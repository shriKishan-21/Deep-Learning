# %%
import tensorflow as tf
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding,SimpleRNN,Dense,LSTM,GRU

# %%
# Load the IMDB Dataset
(x_train,y_train),(x_test,y_test) = imdb.load_data(num_words=10000)

# %%
# Pad Sequences to have the same length
x_train = pad_sequences(x_train,maxlen=100)
x_test = pad_sequences(x_test,maxlen=100)

# %%
# Deep RNN on RNN model

# %%
# Define Model
model = Sequential([
    Embedding(10000,32,input_length=100), # Embedding layer to convert words to vectors
    SimpleRNN(5,return_sequences=True),  # RNN layer with 5 units
    SimpleRNN(5),
    Dense(1,activation='sigmoid')
    
])

# %%
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_5 (Embedding)     (None, 100, 32)           320000
#
#  simple_rnn_4 (SimpleRNN)    (None, 100, 5)            190
#
#  simple_rnn_5 (SimpleRNN)    (None, 5)                 55
#
#  dense_5 (Dense)             (None, 1)                 6
#
# =================================================================
# Total params: 320,251
# Trainable params: 320,251
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
history = model.fit(x_train,y_train,epochs=5,batch_size=32,validation_split=0.2)
# Out:
# Epoch 1/5
# 625/625 [==============================] - 12s 17ms/step - loss: 0.5725 - accuracy: 0.6989 - val_loss: 0.4532 - val_accuracy: 0.8002
# Epoch 2/5
# 625/625 [==============================] - 10s 16ms/step - loss: 0.3655 - accuracy: 0.8487 - val_loss: 0.4345 - val_accuracy: 0.8166
# Epoch 3/5
# 625/625 [==============================] - 10s 17ms/step - loss: 0.2464 - accuracy: 0.9090 - val_loss: 0.4871 - val_accuracy: 0.8066
# Epoch 4/5
# 625/625 [==============================] - 11s 17ms/step - loss: 0.1742 - accuracy: 0.9406 - val_loss: 0.5093 - val_accuracy: 0.8184
# Epoch 5/5
# 625/625 [==============================] - 10s 16ms/step - loss: 0.1363 - accuracy: 0.9545 - val_loss: 0.5545 - val_accuracy: 0.8058

# %%
# DeepRNN on LSTM

# %%
model2 = Sequential([
    Embedding(10000,32,input_length=100),
    LSTM(5,return_sequences=True),
    LSTM(5),
    Dense(1,activation='sigmoid')
])

# %%
model2.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_6 (Embedding)     (None, 100, 32)           320000
#
#  lstm_6 (LSTM)               (None, 100, 5)            760
#
#  lstm_7 (LSTM)               (None, 5)                 220
#
#  dense_6 (Dense)             (None, 1)                 6
#
# =================================================================
# Total params: 320,986
# Trainable params: 320,986
# Non-trainable params: 0
# _________________________________________________________________

# %%
model2.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
history2 = model2.fit(x_train,y_train,epochs=5,batch_size=32,validation_split=0.2)
# Out:
# Epoch 1/5
# 625/625 [==============================] - 17s 24ms/step - loss: 0.4656 - accuracy: 0.7825 - val_loss: 0.3796 - val_accuracy: 0.8348
# Epoch 2/5
# 625/625 [==============================] - 15s 24ms/step - loss: 0.2817 - accuracy: 0.8902 - val_loss: 0.3559 - val_accuracy: 0.8408
# Epoch 3/5
# 625/625 [==============================] - 14s 23ms/step - loss: 0.2057 - accuracy: 0.9247 - val_loss: 0.3798 - val_accuracy: 0.8340
# Epoch 4/5
# 625/625 [==============================] - 15s 23ms/step - loss: 0.1605 - accuracy: 0.9416 - val_loss: 0.4572 - val_accuracy: 0.8298
# Epoch 5/5
# 625/625 [==============================] - 14s 23ms/step - loss: 0.1313 - accuracy: 0.9538 - val_loss: 0.5630 - val_accuracy: 0.8198

# %%
# DeepRNN on GRU

# %%
model3 = Sequential([
    Embedding(10000,32,input_length=100),
    GRU(5,return_sequences=True),
    GRU(5),
    Dense(1,activation='sigmoid')
])

# %%
model3.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_7 (Embedding)     (None, 100, 32)           320000
#
#  gru (GRU)                   (None, 100, 5)            585
#
#  gru_1 (GRU)                 (None, 5)                 180
#
#  dense_7 (Dense)             (None, 1)                 6
#
# =================================================================
# Total params: 320,771
# Trainable params: 320,771
# Non-trainable params: 0
# _________________________________________________________________

# %%
model2.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
history3 = model2.fit(x_train,y_train,epochs=5,batch_size=32,validation_split=0.2)
# Out:
# Epoch 1/5
# 625/625 [==============================] - 17s 24ms/step - loss: 0.1124 - accuracy: 0.9610 - val_loss: 0.5426 - val_accuracy: 0.8266
# Epoch 2/5
# 625/625 [==============================] - 15s 23ms/step - loss: 0.0841 - accuracy: 0.9728 - val_loss: 0.6195 - val_accuracy: 0.8232
# Epoch 3/5
# 625/625 [==============================] - 15s 24ms/step - loss: 0.0742 - accuracy: 0.9760 - val_loss: 0.6315 - val_accuracy: 0.8218
# Epoch 4/5
# 625/625 [==============================] - 14s 23ms/step - loss: 0.0656 - accuracy: 0.9804 - val_loss: 0.6717 - val_accuracy: 0.8228
# Epoch 5/5
# 625/625 [==============================] - 15s 23ms/step - loss: 0.0491 - accuracy: 0.9856 - val_loss: 0.7369 - val_accuracy: 0.8170
